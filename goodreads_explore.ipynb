# %%
import pandas as pd
import json
# Out:
# c:\python38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\python38\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# c:\python38\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df_inter = pd.read_csv('C:/Users/Pratik Acharya/Downloads/goodreads_interactions.csv')

# %%
df_inter.head()
# Out:
#    user_id  book_id  is_read  rating  is_reviewed
# 0        0      948        1       5            0
# 1        0      947        1       5            1
# 2        0      946        1       5            0
# 3        0      945        1       5            0
# 4        0      944        1       5            0

# %%
import gc
gc.collect()
# Out:
# 134

# %%
len(df_inter)
# Out:
# 228648342

# %%
df_inter.describe()
# Out:
#             user_id       book_id       is_read        rating   is_reviewed
# count  2.286483e+08  2.286483e+08  2.286483e+08  2.286483e+08  2.286483e+08
# mean   2.500636e+05  2.015756e+05  4.904090e-01  1.801340e+00  7.093491e-02
# std    1.712713e+05  3.448677e+05  4.999080e-01  2.072672e+00  2.567161e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.143010e+05  1.252700e+04  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    2.338990e+05  5.034600e+04  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    3.581100e+05  2.229240e+05  1.000000e+00  4.000000e+00  0.000000e+00
# max    8.761440e+05  2.360649e+06  1.000000e+00  5.000000e+00  1.000000e+00

# %%
df_inter = df_inter[df_inter.is_read>0]

# %%
df_inter = (df_inter.dropna())

# %%
df_inter.describe()
# Out:
#             user_id       book_id      is_read        rating   is_reviewed
# count  1.121312e+08  1.121312e+08  112131203.0  1.121312e+08  1.121312e+08
# mean   2.591490e+05  1.941018e+05          1.0  3.673138e+00  1.421124e-01
# std    1.820819e+05  3.619385e+05          0.0  1.372808e+00  3.491654e-01
# min    0.000000e+00  0.000000e+00          1.0  0.000000e+00  0.000000e+00
# 25%    1.141430e+05  7.899000e+03          1.0  3.000000e+00  0.000000e+00
# 50%    2.385560e+05  3.685400e+04          1.0  4.000000e+00  0.000000e+00
# 75%    3.720430e+05  1.868890e+05          1.0  5.000000e+00  0.000000e+00
# max    8.761440e+05  2.360649e+06          1.0  5.000000e+00  1.000000e+00

# %%
df_inter = df_inter[df_inter.rating>0]

# %%
df_inter.describe()
# Out:
#          Unnamed: 0       user_id       book_id      is_read        rating  \
# count  1.045515e+08  1.045515e+08  1.045515e+08  104551549.0  1.045515e+08
# mean   1.165093e+08  2.586971e+05  1.902595e+05          1.0  3.939429e+00
# std    6.794251e+07  1.818723e+05  3.595504e+05          0.0  9.860000e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00          1.0  1.000000e+00
# 25%    5.686684e+07  1.136290e+05  7.503000e+03          1.0  3.000000e+00
# 50%    1.163335e+08  2.380770e+05  3.499400e+04          1.0  4.000000e+00
# 75%    1.773203e+08  3.721030e+05  1.798480e+05          1.0  5.000000e+00
# max    2.286483e+08  8.761440e+05  2.360649e+06          1.0  5.000000e+00
#
#         is_reviewed
# count  1.045515e+08
# mean   1.496415e-01
# std    3.567196e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
df_inter = df_inter[df_inter.user_id.isin(df_inter[df_inter.is_reviewed==1].user_id.unique())]

# %%
df_inter#[['book_id']]
# Out:
#            Unnamed: 0  user_id  book_id  is_read  rating  is_reviewed  \
# 0                   0        0      948        1       5            0
# 1                   1        0      947        1       5            1
# 2                   2        0      946        1       5            0
# 3                   3        0      945        1       5            0
# 4                   4        0      944        1       5            0
# ...               ...      ...      ...      ...     ...          ...
# 104551544   228648336   876144   367428        1       3            0
# 104551545   228648338   876144    23847        1       4            0
# 104551546   228648339   876144    23950        1       3            0
# 104551547   228648340   876144   374106        1       5            1
# 104551548   228648341   876144   351607        1       5            1
#
#            book_id_orig
# 0                    12
# 1                    21
# 2                    30
# 3                    45
# ...

# %%
fdict[0]=list(map(int,fdict[0]))

# %%
fdict[0]
# Out:
# [6066819,
#  287149,
#  6066814,
#  89376,
#  89377,
#  89378,
#  18628480,
#  30525379,
#  25317381,
#  23615331,
#  18138604,
#  780911,
#  780912,
#  780917,
#  22642971,
#  17368265,
#  778285,
#  31556136,
#  20924358,
#  14781355,
#  968456,
#  958988,
#  926667,
#  7351310,
#  31124996,
#  6646561,
#  32336119,
#  34680601,
#  388674,
#  388678,
#  18498572,
#  89588,
#  11827783,
#  26160213,
#  17262776,
#  89583,
#  11890856,
#  13519484,
#  13519488,
#  17405342,
#  2741850,
#  2741853,
#  12597209,
#  28820571,
#  117707,
#  12077902,
#  7843586,
#  13569478,
#  16074814,
#  28144874,
#  18663972,
#  22701782,
#  9176116,
#  33022718,
#  18711342,
#  22374354,
#  2168736,
#  18711348,
#  581164,
#  10806009,
#  10806008,
#  581162,
#  10806006,
#  105638,
#  23615336,
#  1403505,
#  351696,
#  13648085,
#  14287198,
#  11731786,
#  11731782,
#  17740337,
#  23615339,
#  9036325,
#  1167728,
#  16114775,
#  16114777,
#  12458828,
#  12458829,
#  9463563,
#  9463561,
# ...

# %%
import pickle
with open('umap_embeddings_dict_eng.pkl', 'rb') as handle:
    fdict = pickle.load(handle)

# %%
# df_inter[['user_id','book_id_orig','rating']].to_csv('filter_final.csv')

# %%
# fdict[0]

# %%
user_embs_dict=dict()
# for k in user_embs_dict:
#     user_embs_dict[k]=

# %%
import numpy as np

# %%
book_embs_dict=dict()
for j in range(len(fdict[0])):
    fdict[1][j][np.isnan(fdict[1][j])]=0.0
    fdict[1][j][fdict[1][j]==np.inf]=100.0
    fdict[1][j][fdict[1][j]==-np.inf]=-100.0
    book_embs_dict[fdict[0][j]]=fdict[1][j]

# %%
# book_embs_dict

# %%
from tqdm.auto import tqdm

# %%
df_inter.rating.describe()
# Out:
# count    8.295965e+07
# mean     3.920519e+00
# std      9.870554e-01
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      4.000000e+00
# 75%      5.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
import numpy as np

# %%
for rw in tqdm(zip(df_inter['user_id'],df_inter['book_id_orig'],df_inter['rating'])):
    if rw[1] not in book_embs_dict:
        continue
#     if rw[0] in user_embs_dict:
    user_embs_dict[rw[0]][0] = np.add(user_embs_dict[rw[0]][0], book_embs_dict[rw[1]]*(rw[2])/user_embs_dict[rw[0]][1]/5.0)
#         user_embs_dict[rw[0]][1]+=1
#     else:
#         user_embs_dict[rw[0]]=[np.zeros_like(book_embs_dict[rw[1]]),1]

# %%
user_embs_dict
# Out:
# {0: [array([6.3911643, 3.8417478, 4.4345603, 4.5449977, 4.1260896, 4.171393 ,
#          3.7170599, 4.4762673, 3.9106703, 5.095785 ], dtype=float32),
#   253],
#  1: [array([6.614998 , 4.742138 , 4.7897005, 4.7492123, 5.1486096, 4.7924757,
#          3.9677525, 4.5838075, 4.0507913, 5.276878 ], dtype=float32),
#   55],
#  2: [array([4.964246 , 3.3668563, 3.2944021, 3.3420343, 3.5847452, 3.3898437,
#          3.051103 , 3.5618863, 2.932044 , 3.9130793], dtype=float32),
#   103],
#  3: [array([5.2669315, 3.687227 , 3.596859 , 3.217032 , 3.9456744, 3.4901145,
#          3.362241 , 3.6984756, 2.8787713, 3.8614495], dtype=float32),
#   27],
#  4: [array([5.0218506, 3.6206512, 3.4822316, 3.3012073, 3.758752 , 3.6079612,
#          3.3678281, 3.47902  , 2.895448 , 3.5726864], dtype=float32),
#   145],
#  5: [array([5.9865236, 4.3929543, 3.9548256, 4.279362 , 4.8084617, 4.6771765,
#          4.1796594, 3.7867544, 3.1377213, 3.8218343], dtype=float32),
#   188],
# ...

# %%
with open('users_final_embs.pickle', 'wb') as handle:
    pickle.dump(user_embs_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df_inter

# %%
al=dict.fromkeys(df_inter.user_id.unique())

# %%
user_embs_dict = {key:val for key,val in tqdm(user_embs_dict.items()) if key in al}

# %%
len(user_embs_dict)
# Out:
# 489144

# %%
df_inter.to_csv('filtered_goodreads_.csv')

# %%
df_inter = df_inter[df_inter.book_id_orig.isin((fdict[0]))]

# %%
len(df_inter.user_id.unique())
# Out:
# 777959

# %%
df_inter.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# c:\python38\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_inter.groupby('user_id').count().quantile(0.95)
# Out:
# book_id         277.0
# is_read         277.0
# rating          277.0
# is_reviewed     277.0
# book_id_orig    277.0
# Name: 0.95, dtype: float64

# %%
df_inter.groupby('user_id').mean().describe()
# Out:
#             book_id   is_read         rating    is_reviewed  book_id_orig
# count  6.380790e+05  638079.0  638079.000000  638079.000000  6.380790e+05
# mean   4.879254e+04       1.0       4.100219       0.076302  6.140854e+06
# std    5.081569e+04       0.0       0.438700       0.160800  4.967069e+06
# min    4.100000e+01       1.0       1.037037       0.000000  3.333333e+00
# 25%    1.609404e+04       1.0       3.812500       0.000000  2.145624e+06
# 50%    3.330337e+04       1.0       4.119266       0.000000  5.005683e+06
# 75%    6.317382e+04       1.0       4.419355       0.080537  9.071202e+06
# max    1.283370e+06       1.0       4.991525       1.000000  3.487697e+07

# %%
s = df_inter.groupby('user_id').count()
s=s[(s.rating>5) & (s.rating<277) & (s.is_reviewed<277)]

# %%
s
# Out:
#         user_id  book_id  is_read  rating  is_reviewed  book_id_orig
# 0             1       55       55      55           55            55
# 1             2      103      103     103          103           103
# 2             3       27       27      27           27            27
# 3             4      145      145     145          145           145
# 4             5      188      188     188          188           188
# ...         ...      ...      ...     ...          ...           ...
# 489139   876135       23       23      23           23            23
# 489140   876140        8        8       8            8             8
# 489141   876141       11       11      11           11            11
# 489142   876142       27       27      27           27            27
# 489143   876143       14       14      14           14            14
#
# [489144 rows x 6 columns]

# %%
s.reset_index(inplace=True)

# %%
df_inter = df_inter[df_inter.user_id.isin(s.user_id.values)]

# %%
df_inter.groupby('user_id').std().describe()
# Out:
#             book_id   is_read         rating    is_reviewed  book_id_orig
# count  7.440210e+05  744021.0  744021.000000  744021.000000  7.440210e+05
# mean   8.186138e+04       0.0       0.804025       0.151553  6.227617e+06
# std    7.376495e+04       0.0       0.311400       0.182355  3.152770e+06
# min    7.071068e-01       0.0       0.000000       0.000000  7.071068e-01
# 25%    2.415613e+04       0.0       0.651452       0.000000  4.061717e+06
# 50%    6.354226e+04       0.0       0.818209       0.000000  6.487632e+06
# 75%    1.202931e+05       0.0       0.981692       0.295098  8.565391e+06
# max    1.204500e+06       0.0       2.828427       0.707107  2.529429e+07

# %%
# df_inter[(df_inter.user_id.isin([443411, 402855,  29261, 313702, 555764, 285884, 142465,  26246,104097, 339833])) & (df_inter.book_id_orig.isin([3,5107,2767052]))]#.book_id_orig.value_counts()

# %%
import random
random.seed(22)

# %%
uidl = list(df_inter['user_id'].unique())

# %%
bidl = list(df_inter['book_id'].unique())

# %%
# bids = random.sample(bidl,1000)
uids = random.sample(uidl,1000)

# %%
df_inter = df_inter[df_inter.book_id.isin(bids)]

# %%
df_inter.iloc[:,1:].to_csv('sample2.csv')

# %%
len(df_inter.user_id.unique())
# Out:
# 489144

# %%
df

# %%
len(df_inter)
# Out:
# 31177398

# %%
df_inter = pd.read_csv('C:/Users/Pratik Acharya/explore_books/sample_seed_22.csv')

# %%
df_inter = pd.read_csv('C:/Users/Pratik Acharya/Downloads/goodreads_interactions_filter.csv')

# %%
df_inter#.head()
# Out:
#            user_id  book_id  is_read  rating  is_reviewed  book_id_orig
# 473              1     1065        1       4            0          2865
# 476              1     1062        1       5            0        381102
# 479              1     1051        1       5            0        228333
# 483              1     1044        1       5            0        452306
# 486              1      846        1       5            0         19543
# ...            ...      ...      ...     ...          ...           ...
# 104551504   876143     7002        1       5            0        688191
# 104551505   876143     5501        1       5            0       6390465
# 104551506   876143     7221        1       4            0      10335308
# 104551507   876143     1611        1       4            0        256683
# 104551508   876143      461        1       5            0          7613
#
# [43580986 rows x 6 columns]

# %%
# bids = ['2767052', '186074', '676924', '59980', '8683812', '6936382', '6320534', '22205', '6068551', '10534', '402093', '8664353', '2233407', '12067', '3431', '6708', '13372690', '16113791', '5060378', '341879', '22754100', '16071764', '162085', '21686', '7677', '7672', '7670', '46787', '228665', '170210', '227443', '96358', '11570', '12751687', '66559', '472331', '270730', '1067', '32423', '15704307', '77203', '8490112', '18122', '6952', '16081272', '10210', '32261', '18660669', '13642', '6339664', '37741', '2282133', '480204', '10664113', '2932', '12609433', '10572', '7260188', '5211', '8621462', '4268157', '9118135', '830', '110494', '14497', '15507958', '101299', '11337', '5139', '25041504', '125507', '13104080', '6567017', '703292', '7747374', '1326258', '9712', '9717', '6487308', '6411961', '16068905', '15196',
'19501', '46799', '17470674', '12262741', '389627', '84119', '168668', '8852', '7604', '5826', '5129', '18619684', '22557272', '34497', '18114322', '3367956', '137791', '32234', '233818', '355697', '50', '43763', '37442', '12996', '6288', '24192', '38709', '2623', '29056083', '1845', '21996', '249747', '37781', '1381', '6482837', '3975774', '960', '968', '33722', '153747', '6149', '6442769', '3478', '4137', '3876', '24770', '49750', '10335308', '7631105', '236093', '186074', '6936382', '8664353', '12067', '5060378', '228665', '472331', '77203', '10210', '2282133', '10664113', '10572', '7260188', '14497', '15507958', '16068905', '16101128', '1885', '140225', '8127', '439288', '15241', '10917', '157993', '4502507', '11127', '13596809', '4948', '11084145', '1217100', '2767052', '4981', '4989', '47281', '39999', '6853', '10614', '9520360', '11387515', '6400090', '6752378', '19063', '15931', '1215032', '128029', '7126', '2728527', '11505797', '345627', '6900', '13145', '10644930', '16299', '168642', '5907', '10964', '5043', '1', '65605', '28186', '28187', '24280', '3950967', '7937843', '1617', '18373', '3412', '4667024', '3609760', '6186357', '2213661', '23772', '21853621', '5', '375802', '60748', '39988', '5470', '10365', '2802316', '99561', '3228917', '9361589', '8442457', '1420', '3591262', '36072', '14891', '113946', '24213', '4406', '4407', '2429135', '76620', '3153910', '5759', '252577', '234225', '7736182', '10025305', '7812659', '38447', '1103', '2657', '18405', '1898', '332613', '233093', '16181775', '13214', '18342', '231804', '6148028', '8908', '4865', '37435', '12691', '2156', '366522', '11486', '2998', '18143977', '3', '32542', '18131', '136251', '12127750', '22034', '100915', '19691', '37470', '22628', '62291', '19543', '6310', '6319', '13496', '13497', '930', '10507293', '19486412', '191139', '3063499', '23807', '15881', '19288043', '7445', '5326', '43641', '7244', '1934', '7144', '256683', '18007564', '7896527', '21787', '11235712', '13158800', '11870085', '3236307', '18512', '13023', '21480930', '11588', '149267', '1232', '556602', '1582996', '30118', '30119', '2', '15745753', '3636', '3777732', '561456', '2120932', '9969571', '320', '5526', '9275658', '29579', '33', '34', '24178', '11735983', '15823480', '6', '14935', '48855', '3473', '7171637', '5297', '13335037', '6892870', '8755776', '6493208', '9791', '11', '370493', '17061']

# %%
book_id_map=pd.read_csv('C:/Users/Pratik Acharya/Downloads/book_id_map (1).csv').to_dict()['book_id']
book_id_map = {v:k for k,v in book_id_map.items()}

# %%
bids = [book_id_map.get(int(x)) for x in bids]

# %%
len([x for x in bids if x!=None])
# Out:
# 2000

# %%
type(bids[0])
# Out:
# int

# %%
df_inter = df_inter[df_inter.book_id.isin(bids)]

# %%
import gc; gc.collect()
# Out:
# 100

# %%
book_id_map_rev = {v:k for k,v in book_id_map.items()}

# %%
df_inter['book_id_orig'] = df_inter['book_id'].map(book_id_map_rev)

# %%
uidl_new = df_inter.groupby('user_id').count().reset_index().sort_values('is_read',ascending=False).head(100000).user_id.values

# %%
book_id_map_rev
# Out:
# {0: 34684622,
#  1: 34536488,
#  2: 34017076,
#  3: 71730,
#  4: 30422361,
#  5: 33503613,
#  6: 33517540,
#  7: 34467031,
#  8: 6383669,
#  9: 486625,
#  10: 19161852,
#  11: 32620335,
#  12: 13152847,
#  13: 25735618,
#  14: 24375664,
#  15: 35097384,
#  16: 34974754,
#  17: 836610,
#  18: 6565837,
#  19: 25899336,
#  20: 26114127,
#  21: 18245960,
#  22: 6392944,
#  23: 22078596,
#  24: 6644782,
#  25: 46164,
#  26: 27833614,
#  27: 10419045,
#  28: 255127,
#  29: 28251002,
#  30: 23168277,
#  31: 32075825,
#  32: 30622471,
#  33: 22591134,
#  34: 31580409,
#  35: 133394,
#  36: 23848190,
#  37: 16130,
#  38: 30139664,
#  39: 32191710,
#  40: 29939161,
#  41: 45252,
#  42: 32283423,
#  43: 43615,
#  44: 29905580,
#  45: 18364442,
#  46: 873993,
#  47: 26721984,
#  48: 8879516,
#  49: 5526,
#  50: 2279538,
#  51: 5043,
#  52: 13543159,
#  53: 18667753,
#  54: 23149647,
#  55: 8138071,
#  56: 7268003,
#  57: 125466,
#  58: 31138556,
#  59: 18633693,
#  60: 15849559,
# ...

# %%
df_inter=df_inter[df_inter.user_id.isin(uidl_new)]

# %%
df_inter=df_inter[df_inter.user_id.isin(uidl_)]

# %%
uidl_= df_inter.groupby('user_id').std().sort_values('rating',ascending=False).head(30000).sample(1000,random_state=22).reset_index().user_id.values

# %%
df_inter#.to_csv('sample_seed_22.csv')
# Out:
#            Unnamed: 0  user_id  book_id  is_read  rating  is_reviewed
# 64961          136861      314     1611        1       2            0
# 64962          136862      314     1000        1       2            0
# 64963          136863      314      837        1       3            0
# 64964          136864      314      536        1       3            0
# 64965          136865      314      821        1       5            0
# ...               ...      ...      ...      ...     ...          ...
# 104162151   228042717   862590     7300        1       3            0
# 104162152   228042718   862590     7135        1       5            0
# 104162166   228042732   862590      430        1       4            0
# 104162173   228042739   862590     6361        1       4            1
# 104162176   228042742   862590     6360        1       4            1
#
# [76870 rows x 6 columns]

# %%
import random
random.seed(22)
uidl = random.sample(list(df_inter.user_id.unique()),1000)

# %%
uidl
# Out:
# [153015,
#  264961,
#  25522,
#  758149,
#  505887,
#  200947,
#  131343,
#  815652,
#  378349,
#  86577,
#  252921,
#  294363,
#  53887,
#  349509,
#  739734,
#  195354,
#  664880,
#  865919,
#  479884,
#  52553,
#  703183,
#  23025,
#  722011,
#  288518,
#  339872,
#  467142,
#  207365,
#  196886,
#  121476,
#  711941,
#  632525,
#  686898,
#  66415,
#  357168,
#  756976,
#  366406,
#  282367,
#  201162,
#  430145,
#  341854,
#  814725,
#  610204,
#  155029,
#  305664,
#  295843,
#  839976,
#  875224,
#  201787,
#  482739,
#  53303,
#  374797,
#  633981,
#  34905,
#  463913,
#  274813,
#  597067,
#  310893,
#  613112,
#  449363,
#  434548,
#  830203,
#  201606,
#  336197,
#  682263,
#  409144,
#  434488,
#  711598,
#  27234,
#  325220,
#  700761,
#  731265,
#  679262,
#  651532,
#  627213,
#  485123,
#  848948,
#  628754,
#  475840,
#  95818,
#  98494,
#  500724,
#  389462,
#  107241,
#  482530,
#  440529,
#  63014,
#  214819,
#  605418,
#  260682,
#  438225,
#  7298,
#  105048,
# ...

# %%
df_inter = df_inter[df_inter.user_id.isin(uidl)]

# %%
df_inter.rating.hist()

# %%
df_inter.rating.hist()

# %%
df_inter.to_csv('C:/Users/Pratik Acharya/Downloads/equal_sample_most_std_.csv')

# %%
# id_counts = df_inter['user_id'].value_counts()
# ids_to_keep = id_counts[id_counts >= 20].index
# df_inter = df_inter.loc[df_inter['user_id'].isin(ids_to_keep)]

# %%
df_inter.sample(5)
# Out:
#            Unnamed: 0  user_id  book_id  is_read  rating  is_reviewed
# 100433001   221555988   678442     7381        1       5            0
# 30801725     67352116   135202     6166        1       3            0
# 28922652     63190423   126691   262380        1       5            0
# 782608        1632794     3224   237810        1       4            0
# 59509992    132995833   274050     6955        1       5            0

# %%
df_inter.iloc[:,1:].describe()
# Out:
#              user_id       book_id   is_read         rating    is_reviewed  \
# count  100914.000000  1.009140e+05  100914.0  100914.000000  100914.000000
# mean   226361.392473  6.312421e+03       1.0       3.683106       0.085588
# std    134423.808290  1.806466e+04       0.0       1.213281       0.279756
# min       438.000000  4.300000e+01       1.0       1.000000       0.000000
# 25%    106458.000000  9.390000e+02       1.0       3.000000       0.000000
# 50%    227418.000000  1.571000e+03       1.0       4.000000       0.000000
# 75%    344601.000000  7.987000e+03       1.0       5.000000       0.000000
# max    764327.000000  1.347842e+06       1.0       5.000000       1.000000
#
#        book_id_orig
# count  1.009140e+05
# mean   2.599092e+06
# std    5.207869e+06
# min    1.000000e+00
# 25%    6.900000e+03
# 50%    3.741500e+04
# 75%    1.656001e+06
# max    3.580032e+07

# %%
len(df_inter.book_id.unique())
# Out:
# 1060

# %%
len(bids)
# Out:
# 1000

# %%
df_inter = pd.read_csv('C:/Users/Pratik Acharya/Downloads/equal_sample_most_std.csv')

# %%
df_inter.iloc[:,2:].describe()#.groupby('is_reviewed').count()#.is_read.hist()
# Out:
#              user_id       book_id   is_read         rating    is_reviewed  \
# count  100914.000000  1.009140e+05  100914.0  100914.000000  100914.000000
# mean   226361.392473  6.312421e+03       1.0       3.683106       0.085588
# std    134423.808290  1.806466e+04       0.0       1.213281       0.279756
# min       438.000000  4.300000e+01       1.0       1.000000       0.000000
# 25%    106458.000000  9.390000e+02       1.0       3.000000       0.000000
# 50%    227418.000000  1.571000e+03       1.0       4.000000       0.000000
# 75%    344601.000000  7.987000e+03       1.0       5.000000       0.000000
# max    764327.000000  1.347842e+06       1.0       5.000000       1.000000
#
#        book_id_orig
# count  1.009140e+05
# mean   2.599092e+06
# std    5.207869e+06
# min    1.000000e+00
# 25%    6.900000e+03
# 50%    3.741500e+04
# 75%    1.656001e+06
# max    3.580032e+07

# %%
len(df_inter.book_id.unique())
# Out:
# 1060

# %%
gc.collect()
# Out:
# 20

# %%
import json
import random
import numpy as np
import os
import snap
from tqdm import tqdm
import torch
from torch_geometric.data import Data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-123-91a47edd14ad> in <module>
#       6 from tqdm import tqdm
#       7 import torch
# ----> 8 from torch_geometric.data import Data
#
# ModuleNotFoundError: No module named 'torch_geometric'
